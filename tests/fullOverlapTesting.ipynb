# %%
import sys, os
sys.path.insert(0, os.path.abspath("../pyCudaPolygon"))
import pyCudaPolygon as pcp
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.animation import FuncAnimation
from pyCudaPolygonLink import libpyCudaPolygon as lpcp

# %%
maxSteps = 20000

# %%
def h(pt1, pt2, startPoint, lam, pref):
    r1 = pt1 - startPoint + 1.5
    r2 = pt2 - startPoint + 1.5
    r1 %= 1
    r2 %= 1
    r1 -= 0.5
    r2 -= 0.5
    d = r2 - r1
    return pref * (r1[0] + r2[0]) * d[1] - lam * np.sqrt(np.sum(d**2))

# %%
def g12(pt1, pt2, startPoint, lam, pref):
    r1 = pt1 - startPoint + 1.5
    r2 = pt2 - startPoint + 1.5
    r1 %= 1
    r2 %= 1
    r1 -= 0.5
    r2 -= 0.5
    d = pt2 - pt1 + 1.5
    d %= 1
    d -= 0.5
    lambd = lam * d / np.sqrt(np.sum(d**2))
    g1x = pref * d[1] + lambd[0]
    g1y = -pref * (r1[0] + r2[0]) + lambd[1]
    g2x = pref * d[1] - lambd[0]
    g2y = pref * (r1[0] + r2[0]) - lambd[1]
    return np.array([g1x, g1y]), np.array([g2x, g2y])

# %%
lam = 0.0
pref = 1
numPolygons = 32
n = 10
nVals = [0, 1, 2, 3, 9,4 ,5, 6, 20, 25, 35, 54]
i = 5
phi = 1.0
kappa = 3.65
m = pcp.model(size = n * numPolygons, seed = i)
m.setModelEnum("normal")
#m.generateRandomPolygons(numPolygons, n, kappa = kappa, phi = phi)
modelDir = "playersTesting/" + str(np.max(np.array(os.listdir("playersTesting")).astype(int)))
m.loadModel(modelDir)
plt.clf()
# Works fine
m.setMaxEdgeLength()
# use default max edge length by finding it within the simulation
# You can adjust this later.
m.initializeNeighborCells()
m.updateNeighborCells()
m.updateNeighbors(0)
overlapArea, force = m.functional(h, g12 = g12, lam = lam, pref = pref)
force0 = m.getConstrainedForce(force)
positions0 = m.getPositions()# Now you have dA, can you draw arrows on the vertices?
artists = m.draw(forces = force0, arrowColor = 'r')

# %%
startPos = m.getPositions()
m.minimizeGD(h = h, g12 = g12, lam = lam, pref = pref, maxSteps = maxSteps, dt = 0.001, progressBar = True, checkpointDir = "playersTesting2", checkpointFreq = 1)
m.initializeNeighborCells()
m.updateNeighborCells()
m.updateNeighbors(0.01)
m.updateContacts()
m.updateOutersections()
overlapArea, force = m.functional(h = h, g12 = g12, lam = lam, pref = pref)
force0 = m.getConstrainedForce(force)
positions0 = m.getPositions()
# Out:
# Processing:   5%|█▏                      | 1031/20000 [12:20<3:44:16,  1.41it/s]/home/rdennis/Documents/Code/pyCudaPolygon/pyCudaPolygon/pyCudaPolygon.py:876: RuntimeWarning: invalid value encountered in double_scalars
#   u = k / w   # kept as requested
# /home/rdennis/Documents/Code/pyCudaPolygon/pyCudaPolygon/pyCudaPolygon.py:901: RuntimeWarning: invalid value encountered in double_scalars
#   du = dk[beta, p] / w - u * dw[beta, p] / w
# /tmp/ipykernel_46128/1701537870.py:11: RuntimeWarning: invalid value encountered in divide
#   lambd = lam * d / np.sqrt(np.sum(d**2))
# /home/rdennis/Documents/Code/pyCudaPolygon/pyCudaPolygon/pyCudaPolygon.py:811: RuntimeWarning: divide by zero encountered in long_scalars
#   mDist = (m + n - i) % n
# /home/rdennis/Documents/Code/pyCudaPolygon/pyCudaPolygon/pyCudaPolygon.py:812: RuntimeWarning: divide by zero encountered in long_scalars
#   lDist = (l + n - i) % n
# Processing:   5%|█▏                      | 1031/20000 [13:23<4:06:15,  1.28it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [6], line 2
#       1 startPos = m.getPositions()
# ----> 2 m.minimizeGD(h = h, g12 = g12, lam = lam, pref = pref, maxSteps = maxSteps, dt = 0.001, progressBar = True, checkpointDir = "playersTesting2", checkpointFreq = 1)
#       3 m.initializeNeighborCells()
#       4 m.updateNeighborCells()
#
# File ~/Documents/Code/pyCudaPolygon/pyCudaPolygon/pyCudaPolygon.py:919, in model.minimizeGD(self, h, g12, lam, pref, dt, maxSteps, addedForce, progressBar, checkpointDir, checkpointFreq)
#     917 if progressBar:
#     918     pbar.update(1)
# --> 919 if (self.minimizeGDStep(h = h, g12 = g12, lam = lam, pref = pref, addedForce = addedForce, dt = dt) == 0):
#     920     return 0
#
# File ~/Documents/Code/pyCudaPolygon/pyCudaPolygon/pyCudaPolygon.py:857, in model.minimizeGDStep(self, h, g12, a, lam, pref, dt, addedForce)
#     855 if (addedForce is not None):
#     856     force += addedForce
# --> 857 force = self.getConstrainedForce(force)
#     858 positions = self.getPositions()
#     859 positions += dt * force
#
# File ~/Documents/Code/pyCudaPolygon/pyCudaPolygon/pyCudaPolygon.py:990, in model.getConstrainedForce(self, force)
#     989 def getConstrainedForce(self, force):
# --> 990     Q = self.getConstraintMatrix()
#     991     numVertices = self.getNumVertices()
#     992     Q2 = Q @ Q.T
#
# File ~/Documents/Code/pyCudaPolygon/pyCudaPolygon/pyCudaPolygon.py:933, in model.getConstraintMatrix(self)
#     931 startIndices = self.getStartIndices()
#     932 for j in range(numVertices):
# --> 933     dp1 = positions[j * 2 : j * 2 + 2] - positions[self.zp(j) * 2 : self.zp(j) * 2 + 2]
#     934     dp2 = positions[self.z(j) * 2 : self.z(j) * 2 + 2] - positions[j * 2 : j * 2 + 2]
#     935     dp3 = positions[self.z(j) * 2 : self.z(j) * 2 + 2] - positions[self.zp(j) * 2 : self.zp(j) * 2 + 2]
#
# ValueError: operands could not be broadcast together with shapes (2,) (0,)

# %%
# fails at 1013 then 1110 then 1031.

# %%
m.setPositions(positions0)

# %%
m.getPositions()

# %%
artists = m.draw(forces = force0, arrowColor = 'r')
