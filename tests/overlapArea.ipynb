# %%
import sys, os
sys.path.insert(0, os.path.abspath("../pyCudaPolygon"))
import pyCudaPolygon as pcp
import numpy as np
from matplotlib import pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [2], line 3
#       1 import sys, os
#       2 sys.path.insert(0, os.path.abspath("../pyCudaPolygon"))
# ----> 3 import pyCudaPolygon as pcp
#       4 import numpy as np
#       5 from matplotlib import pyplot as plt
#
# File ~/Documents/Code/pyCudaPolygon/pyCudaPolygon/pyCudaPolygon.py:3
#       1 #from .pyCudaPolygonLink import libpyCudaPolygon as lpcp
#       2 #from . import enums
# ----> 3 from pyCudaPolygonLink import libpyCudaPolygon as lpcp
#       4 import enums
#       6 import numpy as np
#
# File ~/Documents/Code/pyCudaPolygon/pyCudaPolygon/pyCudaPolygonLink.py:12
#       7 # Adds a relative path to find libpyCudaElasto
#       8 sys.path.append(os.path.join(
#       9     os.path.dirname(__file__), "..", "build"
#      10 ))
# ---> 12 import libpyCudaPolygon
#
# ModuleNotFoundError: No module named 'libpyCudaPolygon'
